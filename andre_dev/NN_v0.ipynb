# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import pandas as pd

# %%
df = pd.read_csv('data/movies_cleaned.csv')

# %%
df1 = df.drop(['Unnamed: 0'], axis=1)

# %%
df1.head()
# Out:
#       profit    budget                                 company country  \
# 0   44287414   8000000           Columbia Pictures Corporation     USA
# 1   64136369   6000000                      Paramount Pictures     USA
# 2  164800601  15000000                      Paramount Pictures     USA
# 3   66660248  18500000  Twentieth Century Fox Film Corporation     USA
# 4    9564613   9000000                    Walt Disney Pictures     USA
#
#          director      genre      gross                      name rating  \
# 0      Rob Reiner  Adventure   52287414               Stand by Me      R
# 1     John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# 2      Tony Scott     Action  179800601                   Top Gun     PG
# 3   James Cameron     Action   85160248                    Aliens      R
# 4  Randal Kleiser  Adventure   18564613   Flight of the Navigator     PG
#
#     released  runtime               star         writer  year      ROI_pct  \
# 0  8/22/1986       89        Wil Wheaton   Stephen King  1986   553.592675
# 1  6/11/1986      103  Matthew Broderick    John Hughes  1986  1068.939483
# 2  5/16/1986      110         Tom Cruise       Jim Cash  1986  1098.670673
# 3  7/18/1986      137   Sigourney Weaver  James Cameron  1986   360.325665
# 4   8/1/1986       90        Joey Cramer  Mark H. Baker  1986   106.273478
#
#    release_dt
# 0  1986-08-22
# 1  1986-06-11
# 2  1986-05-16
# 3  1986-07-18
# 4  1986-08-01

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4638 entries, 0 to 4637
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   profit      4638 non-null   int64
#  1   budget      4638 non-null   int64
#  2   company     4638 non-null   object
#  3   country     4638 non-null   object
#  4   director    4638 non-null   object
#  5   genre       4638 non-null   object
#  6   gross       4638 non-null   int64
#  7   name        4638 non-null   object
#  8   rating      4638 non-null   object
#  9   released    4638 non-null   object
#  10  runtime     4638 non-null   int64
#  11  star        4638 non-null   object
#  12  writer      4638 non-null   object
#  13  year        4638 non-null   int64
#  14  ROI_pct     4638 non-null   float64
#  15  release_dt  4638 non-null   object
# dtypes: float64(1), int64(5), object(10)
# memory usage: 579.9+ KB

# %%
df1['Month_released']=pd.DatetimeIndex(df1['release_dt']).month

# %%
df1.head()
# Out:
#       profit    budget                                 company country  \
# 0   44287414   8000000           Columbia Pictures Corporation     USA
# 1   64136369   6000000                      Paramount Pictures     USA
# 2  164800601  15000000                      Paramount Pictures     USA
# 3   66660248  18500000  Twentieth Century Fox Film Corporation     USA
# 4    9564613   9000000                    Walt Disney Pictures     USA
#
#          director      genre      gross                      name rating  \
# 0      Rob Reiner  Adventure   52287414               Stand by Me      R
# 1     John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# 2      Tony Scott     Action  179800601                   Top Gun     PG
# 3   James Cameron     Action   85160248                    Aliens      R
# 4  Randal Kleiser  Adventure   18564613   Flight of the Navigator     PG
#
#     released  runtime               star         writer  year      ROI_pct  \
# 0  8/22/1986       89        Wil Wheaton   Stephen King  1986   553.592675
# 1  6/11/1986      103  Matthew Broderick    John Hughes  1986  1068.939483
# 2  5/16/1986      110         Tom Cruise       Jim Cash  1986  1098.670673
# 3  7/18/1986      137   Sigourney Weaver  James Cameron  1986   360.325665
# 4   8/1/1986       90        Joey Cramer  Mark H. Baker  1986   106.273478
#
#    release_dt  Month_released
# 0  1986-08-22               8
# 1  1986-06-11               6
# 2  1986-05-16               5
# 3  1986-07-18               7
# 4  1986-08-01               8

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4638 entries, 0 to 4637
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   profit          4638 non-null   int64
#  1   budget          4638 non-null   int64
#  2   company         4638 non-null   object
#  3   country         4638 non-null   object
#  4   director        4638 non-null   object
#  5   genre           4638 non-null   object
#  6   gross           4638 non-null   int64
#  7   name            4638 non-null   object
#  8   rating          4638 non-null   object
#  9   released        4638 non-null   object
#  10  runtime         4638 non-null   int64
#  11  star            4638 non-null   object
#  12  writer          4638 non-null   object
#  13  year            4638 non-null   int64
#  14  ROI_pct         4638 non-null   float64
#  15  release_dt      4638 non-null   object
#  16  Month_released  4638 non-null   int64
# dtypes: float64(1), int64(6), object(10)
# memory usage: 616.1+ KB
